# %% [markdown]
# <a href="https://colab.research.google.com/github/tavoludra1/Datos_Clima_Australlia/blob/master/Datos_Clima_Australia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
# Replace "nombre-de-usuario/nombre-del-conjunto-de-datos" with the dataset handle
# Replace "nombre-del-archivo.csv" with the file name within the dataset
dataset_handle = "arunavakrchakraborty/australia-weather-data"
file_path_train = "Weather Training Data.csv"
file_path_test = "Weather Test Data.csv"

# Load the latest version of the dataset file
try:
  df_train = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    dataset_handle,
    file_path,
    # You can add more arguments here, like version="latest"
    # or pandas_kwargs={'sep': ';'} for specific loading options.
  )
  df_test = kagglehub.load_dataset(
      KaggleDatasetAdapter.PANDAS,
    dataset_handle,
    file_path_test,
    # You can add more arguments here, like version="latest"
    # or pandas_kwargs={'sep': ';'} for specific loading options.
  )

  print(f"Dataset '{dataset_handle}' loaded successfully.")
  print("First 5 records test:")
  display(df_test.head())
  print("First 5 records train:")
  display(df_train.head())


except Exception as e:
  print(f"An error occurred: {e}")
  print("Please check the dataset handle, file path, and ensure the dataset is publicly available on Kaggle.")
# Out:
# /tmp/ipython-input-6-1112348851.py:13: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df_train = kagglehub.load_dataset(
# /tmp/ipython-input-6-1112348851.py:20: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df_test = kagglehub.load_dataset(
# Dataset 'arunavakrchakraborty/australia-weather-data' loaded successfully.
# First 5 records test:
#   row ID Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   Row0   Albury     12.9     25.7       0.0          NaN       NaN
# 1   Row1   Albury      9.2     28.0       0.0          NaN       NaN
# 2   Row2   Albury     14.3     25.0       0.0          NaN       NaN
# 3   Row3   Albury      9.7     31.9       0.0          NaN       NaN
# 4   Row4   Albury     15.9     18.6      15.6          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... WindSpeed3pm  Humidity9am  \
# ...
